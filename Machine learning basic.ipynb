# %% [markdown]
# # Machine learning

# %% [markdown]
# - Supervised Machine Learning
# - Unsupervised Machine Learning
# - Reinforcement Machine Learning
# - Semi Supervised Machine Learning

# %% [markdown]
# # Supervised Machine Learning
# - Regression
# - Classification

# %% [markdown]
# # Regression Analysis

# %%
#Slope  intercept  form
y(Dependent) = c(y-intercept) + (slope)m  x(independent)
#equation of line

y >> output  >> labels/target
x >> input   >> feature
c >> bias
m >> weight

# %%
def line(x):
    y= 2*x+1
    return y

# %%
line(1)
# Out:
# 3
